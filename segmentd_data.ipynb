# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
df=pd.read_csv('gros.csv')

# %%
items=['Order Status','Full Name (Billing)','Name','Quantity','Item Cost','Order Subtotal Amount']
df_new=df[items]

# %%
print(df_new)
df_new.dropna()
# Out:
#      Order Status Full Name (Billing)  \
# 0         On hold         Peter Manic
# 1         On hold         Peter Manic
# 2         On hold         Peter Manic
# 3         On hold         Peter Manic
# 4         On hold         Peter Manic
# 5         On hold         Peter Manic
# 6         On hold         Peter Manic
# 7       Completed        Rajaprabhu P
# 8       Completed        Rajaprabhu P
# 9       Completed        Rajaprabhu P
# 10      Completed      Sudha Gayathri
# 11      Completed      Sudha Gayathri
# 12      Completed      Sudha Gayathri
# 13      Completed      Sudha Gayathri
# 14      Completed      Sudha Gayathri
# 15        On hold          Dinesh CPS
# 16        On hold          Dinesh CPS
# 17        On hold          Dinesh CPS
# 18        On hold          Dinesh CPS
# 19        On hold      K Paramashivam
# 20        On hold      K Paramashivam
# 21        On hold      K Paramashivam
# 22        On hold      K Paramashivam
# ...

# %% [markdown]
# there are four catogories of price range in which people are shopping:

# %% [markdown]
# 1)0-100: "low valued customers"-the number is aproximately 15.38% of total customers(in given dataset aprox 2 out of 13). these catogory of people are purchaging either general low price things like low cost vegetables and some common buiscuits.

# %% [markdown]
# 2)101-500:"average valued customers"-- the count of these customers are aprox 53.84% of total customers. these customers are middle class people who only are interested in buying very necessary things for household like soap, shampoo, cofee, milk etc..they are not intrested in purchaging things without which they can survive.

# %% [markdown]
# 3)501-1000: "above average valued customers"-- 23.07% of total customers. these people purchage household things in a bulk amount for a bit long period. they are also intrested in extra things than regular use household like juice, suop etc..

# %% [markdown]
# 4)1001-3000: "high valued customers" who are more bothered about quality and brand of the product than price of the product. they like to spend on porche and expensive things like dryfruits, all the product of best quality.

# %% [markdown]
# now the segmentation is done on the basis of age group:

# %%
items_new=['Full Name (Billing)','Name','Quantity']
df_new1= df[items_new]
print(df_new1)
df_new1.dropna()
# Out:
#      Full Name (Billing)                                               Name  \
# 0            Peter Manic                     Organic Banana (Elakki) 500gms
# 1            Peter Manic                    Organic Tomato (Country) 500gms
# 2            Peter Manic                       Organic Onion (Small) 500gms
# 3            Peter Manic                       Organic Mint Leaves (Pudina)
# 4            Peter Manic                 Organic Coriander Leaves - 1 Piece
# 5            Peter Manic                              Organic Carrot 500gms
# 6            Peter Manic                     Organic Curry Leaves - 1 Piece
# 7           Rajaprabhu P                 Cold Pressed Gingelly Oil - 1Litre
# 8           Rajaprabhu P                Cold Pressed Groundnut Oil - 1Litre
# 9           Rajaprabhu P                 Cold Pressed Groundnut Oil - 500ML
# 10        Sudha Gayathri                       Cluster Beans (Gawar) 500gms
# ...

# %% [markdown]
# 1)23-30: mostly bachlors. as the people who are purchasing cold pressed items must be concious about the durability of products and will be thinking of taking the products which are ready made and easy to cook. so these types of activity may be expected from the batchlors staying away from family

# %% [markdown]
# 2)31-37: these are the group of people mostly married. these people are purchasing general food items with more veriety and and trendy food like soup and juice as tropicana pomegranate.

# %% [markdown]
# 3) 37-43: this is the age group having not much cocern about price but about the quality. They are more health concious as in this age people will get disease like blood pressure and blood sugar. so they will go for organic items more preferably.
